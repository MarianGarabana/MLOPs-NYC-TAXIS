# %% [markdown]
# ## Scenario 2: A cross-functional team with one data scientist working on an ML model
#
# This scenario demonstrates how a data scientist can use MLflow to track machine learning experiments in a team setting, using a centralized tracking server. This setup is common in organizations where multiple people need to access experiment results, models, and artifacts.
#
# ### MLflow setup overview:
# - **Tracking server:** Yes (runs as a local server, accessible to the team)
# - **Backend store:** SQLite database (stores experiment metadata in `backend.db`)
# - **Artifacts store:** Local filesystem (stores model files and other artifacts)
#
# With this setup, all experiment runs, parameters, metrics, and artifacts are saved in a central location. Team members can explore and compare experiments using the MLflow UI, even from different machines (if the server is accessible).
#
# ### How to use the MLflow tracking server and UI
# - **First, you must launch the MLflow tracking server** by running the following command in your terminal:
#   ```bash
#   mlflow server --backend-store-uri sqlite:///backend.db
#   ```
# - The UI will be available at the address printed in your terminal (by default, [http://localhost:5000](http://localhost:5000)).
# - If you run the server on a remote machine or a different port, use the appropriate address (e.g., `http://<your-server>:<port>`).
# - Use the UI to browse experiments, compare runs, and inspect logged models and artifacts.
# - You can also interact with the model registry for collaborative model management.
#
# > **Tip:** This setup is ideal for small teams and collaborative projects. For larger teams or production, you may use a remote database and cloud storage for the backend and artifacts.

# %% [markdown]
# mlflow server --backend-store-uri sqlite:///backend.db --port 5001

# %%
import mlflow


mlflow.set_tracking_uri("http://127.0.0.1:5001")

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'http://127.0.0.1:5001'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1772556137513, experiment_id='0', last_update_time=1772556137513, lifecycle_stage='active', name='Default', tags={}, workspace='default'>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import mlflow
import sklearn
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mlflow.set_experiment("my-experiment-1")

X, y = load_iris(return_X_y=True)
class_names = load_iris().target_names

# Try several values of C to demonstrate experiment tracking
for C in [0.01, 0.1, 1, 10]:
    params = {"C": C, "random_state": 42, "max_iter": 1000, "solver": "lbfgs"}
    with mlflow.start_run() as run:
        mlflow.log_params(params)
        mlflow.log_param("sklearn_version", sklearn.__version__)
        lr = LogisticRegression(**params).fit(X, y)
        y_pred = lr.predict(X)
        acc = accuracy_score(y, y_pred)
        mlflow.log_metric("accuracy", acc)
        # Log model coefficients as params (flattened for logging)
        for i, coef in enumerate(lr.coef_.flatten()):
            mlflow.log_param(f"coef_{i}", coef)
        # Labeled confusion matrix as DataFrame
        cm = confusion_matrix(y, y_pred)
        cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
        cm_df.to_csv("confusion_matrix_labeled.csv")
        mlflow.log_artifact("confusion_matrix_labeled.csv")
        # Confusion matrix heatmap as image
        plt.figure(figsize=(5,4))
        sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
        plt.title(f"Confusion Matrix (C={C})")
        plt.ylabel("True label")
        plt.xlabel("Predicted label")
        plt.tight_layout()
        plt.savefig("confusion_matrix_heatmap.png")
        plt.close()
        mlflow.log_artifact("confusion_matrix_heatmap.png")
        # Provide input_example and use 'name' instead of deprecated 'artifact_path'
        input_example = np.expand_dims(X[0], axis=0)
        mlflow.sklearn.log_model(lr, name="models", input_example=input_example)
        # Log model type, number of classes, and timestamp as tags
        mlflow.set_tag("model_type", type(lr).__name__)
        mlflow.set_tag("n_classes", len(np.unique(y)))
        mlflow.set_tag("run_time", datetime.datetime.now().isoformat())
        mlflow.set_tag("description", "Logistic regression on Iris dataset with varying C")
        print(f"Logged run for C={C}, accuracy={acc:.3f}")
# Out:
# 2026/03/03 17:49:02 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2026/03/03 17:49:02 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Logged run for C=0.01, accuracy=0.873
# 🏃 View run grandiose-skink-120 at: http://127.0.0.1:5001/#/experiments/1/runs/a9b8198970b045e685aefc441115a5f9
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/1
# 2026/03/03 17:49:08 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Logged run for C=0.1, accuracy=0.960
# 🏃 View run valuable-squid-284 at: http://127.0.0.1:5001/#/experiments/1/runs/cfef1dca47b24d69abba7486ce44faa1
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/1
# 2026/03/03 17:49:11 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Logged run for C=1, accuracy=0.973
# 🏃 View run chill-cow-819 at: http://127.0.0.1:5001/#/experiments/1/runs/7ee3c0d91f5a4a149ec5a3f8034062f3
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/1
# 2026/03/03 17:49:15 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Logged run for C=10, accuracy=0.980
# 🏃 View run delightful-duck-153 at: http://127.0.0.1:5001/#/experiments/1/runs/549c29556c914242a413bb433365ccce
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/1

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1772556542430, experiment_id='1', last_update_time=1772556542430, lifecycle_stage='active', name='my-experiment-1', tags={}, workspace='default'>,
#  <Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1772556137513, experiment_id='0', last_update_time=1772556137513, lifecycle_stage='active', name='Default', tags={}, workspace='default'>]

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient("http://127.0.0.1:5000")

# %%
client.search_registered_models()
# Out:
# [<RegisteredModel: aliases={}, creation_timestamp=1772555598355, deployment_job_id='', deployment_job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', description='', last_updated_timestamp=1772555598419, latest_versions=[<ModelVersion: aliases=[], creation_timestamp=1772555598419, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1772555598419, metrics=None, model_id=None, name='iris-classifier', params=None, run_id='ec45fe604e35445286cc33ac4c152c48', run_link='', source='models:/m-cbf5d67138c64c9ab85ebf11e7bfdaff', status='READY', status_message=None, tags={}, user_id='', version='1', workspace='default'>], name='iris-classifier', tags={}, workspace='default'>]

# %%
run_id = client.search_runs(experiment_ids='1')[0].info.run_id
mlflow.register_model(
    model_uri=f"runs:/{run_id}/models",
    name='iris-classifier'
)
# Out:
# Successfully registered model 'iris-classifier'.
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[8], line 2
#       1 run_id = client.search_runs(experiment_ids='1')[0].info.run_id
# ----> 2 mlflow.register_model(
#       3     model_uri=f"runs:/{run_id}/models",
#       4     name='iris-classifier'
#       5 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/mlflow/tracking/_model_registry/fluent.py:136, in register_model(model_uri, name, await_registration_for, tags, env_pack)
#      66 def register_model(
#      67     model_uri,
#      68     name,
#    (...)
#      72     env_pack: EnvPackType | EnvPackConfig | None = None,
#      73 ) -> ModelVersion:
#      74     """Create a new model version in model registry for the model files specified by ``model_uri``.
#      75
#      76     Note that this method assumes the model registry backend URI is the same as that of the
#    (...)
#     134         Version: 1
#     135     """
# --> 136     return _register_model(
#     137         model_uri=model_uri,
#     138         name=name,
#     139         await_registration_for=await_registration_for,
#     140         tags=tags,
#     141         env_pack=env_pack,
#     142     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/mlflow/tracking/_model_registry/fluent.py:175, in _register_model(model_uri, name, await_registration_for, tags, local_model_path, env_pack)
#     172 if RunsArtifactRepository.is_runs_uri(model_uri):
#     173     # If the uri is of the form runs:/...
#     174     (run_id, artifact_path) = RunsArtifactRepository.parse_runs_uri(model_uri)
# --> 175     runs_artifact_repo = RunsArtifactRepository(model_uri)
#     176     # List artifacts in `<run_artifact_root>/<artifact_path>` to see if the run has artifacts.
#     177     # If so use the run's artifact location as source.
#     178     artifacts = runs_artifact_repo._list_run_artifacts()
#
# File /opt/anaconda3/lib/python3.13/site-packages/mlflow/store/artifact/runs_artifact_repo.py:38, in RunsArtifactRepository.__init__(self, artifact_uri, tracking_uri, registry_uri)
#      35 from mlflow.store.artifact.artifact_repository_registry import get_artifact_repository
#      37 super().__init__(artifact_uri, tracking_uri, registry_uri)
# ---> 38 uri = RunsArtifactRepository.get_underlying_uri(artifact_uri, tracking_uri)
#      39 self.repo = get_artifact_repository(
#      40     uri, tracking_uri=self.tracking_uri, registry_uri=self.registry_uri
#      41 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/mlflow/store/artifact/runs_artifact_repo.py:53, in RunsArtifactRepository.get_underlying_uri(runs_uri, tracking_uri)
#      51 (run_id, artifact_path) = RunsArtifactRepository.parse_runs_uri(runs_uri)
#      52 databricks_profile_uri = get_databricks_profile_uri_from_artifact_uri(runs_uri)
# ---> 53 uri = get_artifact_uri(
#      54     run_id=run_id,
#      55     artifact_path=artifact_path,
#      56     tracking_uri=databricks_profile_uri or tracking_uri,
#      57 )
#      58 assert not RunsArtifactRepository.is_runs_uri(uri)  # avoid an infinite loop
#      59 return add_databricks_profile_info_to_artifact_uri(
#      60     artifact_uri=uri, databricks_profile_uri=databricks_profile_uri or tracking_uri
#      61 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/mlflow/tracking/artifact_utils.py:53, in get_artifact_uri(run_id, artifact_path, tracking_uri)
#      47     raise MlflowException(
#      48         message="A run_id must be specified in order to obtain an artifact uri!",
#      49         error_code=INVALID_PARAMETER_VALUE,
#      50     )
#      52 store = _get_store(tracking_uri)
# ---> 53 run = store.get_run(run_id)
#      54 # Maybe move this method to RunsArtifactRepository so the circular dependency is clearer.
#      55 assert urllib.parse.urlparse(run.info.artifact_uri).scheme != "runs"  # avoid an infinite loop
#
# File /opt/anaconda3/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:327, in RestStore.get_run(self, run_id)
#     317 """
#     318 Fetch the run from backend store
#     319
#    (...)
#     324     A single Run object if it exists, otherwise raises an Exception
#     325 """
#     326 req_body = message_to_json(GetRun(run_uuid=run_id, run_id=run_id))
# --> 327 response_proto = self._call_endpoint(GetRun, req_body)
#     328 return Run.from_proto(response_proto.run)
#
# File /opt/anaconda3/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:233, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     231     endpoint, method = method_to_info[api]
#     232 response_proto = response_proto or api.Response()
# --> 233 return call_endpoint(
#     234     self.get_host_creds(),
#     235     endpoint,
#     236     method,
#     237     json_body,
#     238     response_proto,
#     239     retry_timeout_seconds=retry_timeout_seconds,
#     240 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:627, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds, expected_status)
#     624     call_kwargs["json"] = json_body
#     625     response = http_request(**call_kwargs)
# --> 627 response = verify_rest_response(
#     628     response,
#     629     endpoint,
#     630     expected_status=expected_status,
#     631 )
#     632 if response.status_code == 204:
#     633     return response_proto
#
# File /opt/anaconda3/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:341, in verify_rest_response(response, endpoint, expected_status)
#     339 if response.status_code != expected_status:
#     340     if _can_parse_as_json_object(response.text):
# --> 341         raise RestException(json.loads(response.text))
#     342     else:
#     343         base_msg = (
#     344             f"API request to endpoint {endpoint} "
#     345             f"failed with error code {response.status_code} "
#     346             f"!= {expected_status}"
#     347         )
#
# RestException: RESOURCE_DOES_NOT_EXIST: Run with id=ec45fe604e35445286cc33ac4c152c48 not found
